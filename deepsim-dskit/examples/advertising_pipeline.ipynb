# %% [markdown]
# # Advertising Pipeline
#
# This notebook mirrors `examples/advertising_pipeline.py`. Run the script for the fastest offline smoke test.

# %%
from examples.advertising_pipeline import main

main()
